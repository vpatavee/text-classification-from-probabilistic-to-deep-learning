# %%
from gensim.models import Word2Vec, KeyedVectors
from nlp_utils import spacy_tokenizer_lower_lemma_remove_stop, preprocess_remove_html_non_ascii, spacy_tokenizer,spacy_tokenizer_remove_stop
import spacy
from dataset import download_tfds_imdb_as_text
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# case, not sentenize
# uncase, not sentenize
# uncase, sentenize
# uncase, sentenize, replace punct, number, email, url
#
# dim
#
# 300
# 200
# 100
#
# windows
# 5
# 15
# 30
# 50
#
#
# iter
# 5,10,20

# %%
X_train, X_test, y_train, y_test = download_tfds_imdb_as_text()
X_train_preprocessed = [preprocess_remove_html_non_ascii(doc) for doc in X_train]
X_train_spacy = [doc for doc in nlp.pipe(X_train_preprocessed, n_threads=8)]
# Out:
# number of training samples 25000
# number of testing samples 25000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-7313d61e0651> in <module>
#       1 X_train, X_test, y_train, y_test = download_tfds_imdb_as_text()
#       2 X_train_preprocessed = [preprocess_remove_html_non_ascii(doc) for doc in X_train]
# ----> 3 X_train_spacy = [doc for doc in nlp.pipe(X_train_preprocessed, n_threads=8)]
#
# <ipython-input-2-7313d61e0651> in <listcomp>(.0)
#       1 X_train, X_test, y_train, y_test = download_tfds_imdb_as_text()
#       2 X_train_preprocessed = [preprocess_remove_html_non_ascii(doc) for doc in X_train]
# ----> 3 X_train_spacy = [doc for doc in nlp.pipe(X_train_preprocessed, n_threads=8)]
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/spacy/language.py in pipe(self, texts, as_tuples, n_threads, batch_size, disable, cleanup, component_cfg, n_process)
#     817         original_strings_data = None
#     818         nr_seen = 0
# --> 819         for doc in docs:
#     820             yield doc
#     821             if cleanup:
#
# nn_parser.pyx in pipe()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.predict()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.greedy_parse()
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     165             Must match expected shape
#     166         """
# --> 167         return self.predict(x)
#     168
#     169     def pipe(self, stream, batch_size=128):
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/thinc/neural/_classes/model.py in predict(self, X)
#     129
#     130     def predict(self, X):
# --> 131         y, _ = self.begin_update(X, drop=None)
#     132         return y
#     133
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserModel.begin_update()
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserStepModel.__init__()
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/thinc/api.py in begin_update(seqs_in, drop)
#     293     def begin_update(seqs_in, drop=0.0):
#     294         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 295         X, bp_layer = layer.begin_update(layer.ops.flatten(seqs_in, pad=pad), drop=drop)
#     296         if bp_layer is None:
#     297             return layer.ops.unflatten(X, lengths, pad=pad), None
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/thinc/neural/_classes/resnet.py in begin_update(self, X, drop)
#      27
#      28     def begin_update(self, X, drop=0.0):
# ---> 29         y, bp_y = self._layers[0].begin_update(X, drop=drop)
#      30         if isinstance(X, list):
#      31             output = [X[i] + y[i] for i in range(len(X))]
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/thinc/neural/_classes/layernorm.py in begin_update(self, X, drop)
#      60     def begin_update(self, X, drop=0.0):
#      61         if self.child is not None:
# ---> 62             X, backprop_child = self.child.begin_update(X, drop=0.0)
#      63         else:
#      64             backprop_child = None
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/thinc/neural/_classes/maxout.py in begin_update(self, X__bi, drop)
#      74         if drop is not None:
#      75             drop *= self.drop_factor
# ---> 76         output__boc = self.ops.gemm(X__bi, W, trans2=True)
#      77         output__boc += self.b.reshape((self.nO * self.nP,))
#      78         output__boc = output__boc.reshape((output__boc.shape[0], self.nO, self.nP))
#
# KeyboardInterrupt:

# %%
def sub(tok):
    if tok.is_digit and tok.like_num:
        return "<<DIGIT>>"
    if tok.is_space:
        return " "
    if tok.like_url:
        return "<<URL>>"
    if tok.like_email:
        return "<<EMAIL>>"
    if tok.is_currency:
        return "<<$$>>"
    if tok.is_punct:
        return "<<PUNCT>>"
    
    return tok.orth_



case = [ [tok.orth_ for tok in doc] for doc in X_train_spacy]
uncase = [ [tok.orth_.lower() for tok in doc] for doc in X_train_spacy]
uncase_sent = [ [tok.orth_.lower() for tok in sent] for doc in X_train_spacy for sent in doc.sents]
uncase_sent_sub = [ [sub(tok) for tok in sent] for doc in X_train_spacy for sent in doc.sents]

corpus = {"case": case, "uncase": uncase, "uncase_sent":uncase_sent,"uncase_sent_sub":uncase_sent_sub}

dims = [300, 200, 100]
windows = [5,15,30,50]
iters = [5,10,20]

# %%
for nc, c in corpus.items():
    for d in dims:
        for w in windows:
            for ite in iters:
                name = "{}_{}_{}_{}".format(nc, str(d), str(w), ite)
                print(name)
                model = Word2Vec(c, size=d, window=w, min_count=1, workers=4, sg=1, iter=ite)
                model.save(name)
# Out:
# case_300_5_5
# case_300_5_10
# case_300_5_20
# case_300_15_5
# case_300_15_10
# case_300_15_20
# case_300_30_5
# case_300_30_10
# case_300_30_20
# case_300_50_5
# case_300_50_10
# case_300_50_20
# case_200_5_5
# case_200_5_10
# case_200_5_20
# case_200_15_5
# case_200_15_10
# case_200_15_20
# case_200_30_5
# case_200_30_10
# case_200_30_20
# case_200_50_5
# case_200_50_10
# case_200_50_20
# case_100_5_5
# case_100_5_10
# case_100_5_20
# case_100_15_5
# case_100_15_10
# case_100_15_20
# case_100_30_5
# case_100_30_10
# case_100_30_20
# case_100_50_5
# case_100_50_10
# case_100_50_20
# uncase_300_5_5
# uncase_300_5_10
# uncase_300_5_20
# uncase_300_15_5
# uncase_300_15_10
# uncase_300_15_20
# uncase_300_30_5
# uncase_300_30_10
# uncase_300_30_20
# uncase_300_50_5
# uncase_300_50_10
# uncase_300_50_20
# uncase_200_5_5
# uncase_200_5_10
# uncase_200_5_20
# uncase_200_15_5
# uncase_200_15_10
# uncase_200_15_20
# uncase_200_30_5
# uncase_200_30_10
# uncase_200_30_20
# uncase_200_50_5
# uncase_200_50_10
# uncase_200_50_20
# uncase_100_5_5
# uncase_100_5_10
# uncase_100_5_20
# uncase_100_15_5
# uncase_100_15_10
# uncase_100_15_20
# uncase_100_30_5
# uncase_100_30_10
# uncase_100_30_20
# uncase_100_50_5
# uncase_100_50_10
# uncase_100_50_20
# uncase_sent_300_5_5
# uncase_sent_300_5_10
# uncase_sent_300_5_20
# uncase_sent_300_15_5
# uncase_sent_300_15_10
# uncase_sent_300_15_20
# uncase_sent_300_30_5
# uncase_sent_300_30_10
# uncase_sent_300_30_20
# uncase_sent_300_50_5
# uncase_sent_300_50_10
# uncase_sent_300_50_20
# uncase_sent_200_5_5
# uncase_sent_200_5_10
# uncase_sent_200_5_20
# uncase_sent_200_15_5
# uncase_sent_200_15_10
# uncase_sent_200_15_20
# uncase_sent_200_30_5
# uncase_sent_200_30_10
# uncase_sent_200_30_20
# uncase_sent_200_50_5
# uncase_sent_200_50_10
# uncase_sent_200_50_20
# uncase_sent_100_5_5
# uncase_sent_100_5_10
# uncase_sent_100_5_20
# uncase_sent_100_15_5
# uncase_sent_100_15_10
# uncase_sent_100_15_20
# uncase_sent_100_30_5
# uncase_sent_100_30_10
# uncase_sent_100_30_20
# uncase_sent_100_50_5
# uncase_sent_100_50_10
# uncase_sent_100_50_20
# uncase_sent_sub_300_5_5
# uncase_sent_sub_300_5_10
# uncase_sent_sub_300_5_20
# uncase_sent_sub_300_15_5
# uncase_sent_sub_300_15_10
# uncase_sent_sub_300_15_20
# uncase_sent_sub_300_30_5
# uncase_sent_sub_300_30_10
# uncase_sent_sub_300_30_20
# uncase_sent_sub_300_50_5
# uncase_sent_sub_300_50_10
# uncase_sent_sub_300_50_20
# uncase_sent_sub_200_5_5
# uncase_sent_sub_200_5_10
# uncase_sent_sub_200_5_20
# uncase_sent_sub_200_15_5
# uncase_sent_sub_200_15_10
# uncase_sent_sub_200_15_20
# uncase_sent_sub_200_30_5
# uncase_sent_sub_200_30_10
# uncase_sent_sub_200_30_20
# uncase_sent_sub_200_50_5
# uncase_sent_sub_200_50_10
# uncase_sent_sub_200_50_20
# uncase_sent_sub_100_5_5
# uncase_sent_sub_100_5_10
# uncase_sent_sub_100_5_20
# uncase_sent_sub_100_15_5
# uncase_sent_sub_100_15_10
# uncase_sent_sub_100_15_20
# uncase_sent_sub_100_30_5
# uncase_sent_sub_100_30_10
# uncase_sent_sub_100_30_20
# uncase_sent_sub_100_50_5
# uncase_sent_sub_100_50_10
# uncase_sent_sub_100_50_20

# %%
from word_emb import run_logistic_word_emb_exp

# %%
from gensim.models import Word2Vec
li="""uncase_sent_300_5_5
uncase_sent_300_5_10
uncase_sent_300_5_20
uncase_sent_300_15_5
uncase_sent_300_15_10
uncase_sent_300_15_20
uncase_sent_300_30_5
uncase_sent_300_30_10
uncase_sent_300_30_20
uncase_sent_300_50_5
uncase_sent_300_50_10
uncase_sent_300_50_20
uncase_sent_200_5_5
uncase_sent_200_5_10
uncase_sent_200_5_20
uncase_sent_200_15_5
uncase_sent_200_15_10
uncase_sent_200_15_20
uncase_sent_200_30_5
uncase_sent_200_30_10
uncase_sent_200_30_20
uncase_sent_200_50_5
uncase_sent_200_50_10
uncase_sent_200_50_20
uncase_sent_100_5_5
uncase_sent_100_5_10
uncase_sent_100_5_20
uncase_sent_100_15_5
uncase_sent_100_15_10
uncase_sent_100_15_20
uncase_sent_100_30_5
uncase_sent_100_30_10
uncase_sent_100_30_20
uncase_sent_100_50_5
uncase_sent_100_50_10
uncase_sent_100_50_20""".split('\n')

models = {e:Word2Vec.load(e) for e in li}


run_logistic_word_emb_exp(X_train, X_test, y_train, y_test, models)


# word2vec.model.240.10.10.filtered 88.15
# Out:
# /Users/pataveemeemeng/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/pataveemeemeng/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/pataveemeemeng/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#            word_emb_model  tfidf              tokenizer polling        F1
# 0     uncase_sent_300_5_5  False  spacy_tokenizer_lower     LOG  0.867782
# 1    uncase_sent_300_5_10  False  spacy_tokenizer_lower     LOG  0.870100
# 2    uncase_sent_300_5_20  False  spacy_tokenizer_lower     LOG  0.870390
# 3    uncase_sent_300_15_5  False  spacy_tokenizer_lower     LOG  0.875523
# 4   uncase_sent_300_15_10  False  spacy_tokenizer_lower     LOG  0.873086
# 5   uncase_sent_300_15_20  False  spacy_tokenizer_lower     LOG  0.870805
# 6    uncase_sent_300_30_5  False  spacy_tokenizer_lower     LOG  0.879348
# 7   uncase_sent_300_30_10  False  spacy_tokenizer_lower     LOG  0.874386
# 8   uncase_sent_300_30_20  False  spacy_tokenizer_lower     LOG  0.871909
# 9    uncase_sent_300_50_5  False  spacy_tokenizer_lower     LOG  0.877327
# 10  uncase_sent_300_50_10  False  spacy_tokenizer_lower     LOG  0.873641
# 11  uncase_sent_300_50_20  False  spacy_tokenizer_lower     LOG  0.872118
# 12    uncase_sent_200_5_5  False  spacy_tokenizer_lower     LOG  0.858762
# 13   uncase_sent_200_5_10  False  spacy_tokenizer_lower     LOG  0.865566
# 14   uncase_sent_200_5_20  False  spacy_tokenizer_lower     LOG  0.866255
# 15   uncase_sent_200_15_5  False  spacy_tokenizer_lower     LOG  0.874302
# 16  uncase_sent_200_15_10  False  spacy_tokenizer_lower     LOG  0.872785
# 17  uncase_sent_200_15_20  False  spacy_tokenizer_lower     LOG  0.868363
# 18   uncase_sent_200_30_5  False  spacy_tokenizer_lower     LOG  0.874301
# 19  uncase_sent_200_30_10  False  spacy_tokenizer_lower     LOG  0.873867
# 20  uncase_sent_200_30_20  False  spacy_tokenizer_lower     LOG  0.868946
# 21   uncase_sent_200_50_5  False  spacy_tokenizer_lower     LOG  0.873418
# 22  uncase_sent_200_50_10  False  spacy_tokenizer_lower     LOG  0.870917
# 23  uncase_sent_200_50_20  False  spacy_tokenizer_lower     LOG  0.869730
# 24    uncase_sent_100_5_5  False  spacy_tokenizer_lower     LOG  0.849741
# 25   uncase_sent_100_5_10  False  spacy_tokenizer_lower     LOG  0.855292
# 26   uncase_sent_100_5_20  False  spacy_tokenizer_lower     LOG  0.857419
# 27   uncase_sent_100_15_5  False  spacy_tokenizer_lower     LOG  0.864995
# 28  uncase_sent_100_15_10  False  spacy_tokenizer_lower     LOG  0.867230
# 29  uncase_sent_100_15_20  False  spacy_tokenizer_lower     LOG  0.862295
# 30   uncase_sent_100_30_5  False  spacy_tokenizer_lower     LOG  0.868635
# 31  uncase_sent_100_30_10  False  spacy_tokenizer_lower     LOG  0.865085
# 32  uncase_sent_100_30_20  False  spacy_tokenizer_lower     LOG  0.865369
# 33   uncase_sent_100_50_5  False  spacy_tokenizer_lower     LOG  0.869045
# 34  uncase_sent_100_50_10  False  spacy_tokenizer_lower     LOG  0.867276
# 35  uncase_sent_100_50_20  False  spacy_tokenizer_lower     LOG  0.861732

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-446add96efa2> in <module>
#      37 uncase_sent_sub_100_50_20""".split('\n')
#      38
# ---> 39 models = {e:Word2Vec.load(e) for e in li}
#      40
#      41
#
# <ipython-input-7-446add96efa2> in <dictcomp>(.0)
#      37 uncase_sent_sub_100_50_20""".split('\n')
#      38
# ---> 39 models = {e:Word2Vec.load(e) for e in li}
#      40
#      41
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/gensim/models/word2vec.py in load(cls, *args, **kwargs)
#    1328         """
#    1329         try:
# -> 1330             model = super(Word2Vec, cls).load(*args, **kwargs)
#    1331
#    1332             # for backward compatibility for `max_final_vocab` feature
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/gensim/models/base_any2vec.py in load(cls, *args, **kwargs)
#    1242
#    1243         """
# -> 1244         model = super(BaseWordEmbeddingsModel, cls).load(*args, **kwargs)
#    1245         if not hasattr(model, 'ns_exponent'):
#    1246             model.ns_exponent = 0.75
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/gensim/models/base_any2vec.py in load(cls, fname_or_handle, **kwargs)
#     601
#     602         """
# --> 603         return super(BaseAny2VecModel, cls).load(fname_or_handle, **kwargs)
#     604
#     605     def save(self, fname_or_handle, **kwargs):
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/gensim/utils.py in load(cls, fname, mmap)
#     425
#     426         obj = unpickle(fname)
# --> 427         obj._load_specials(fname, mmap, compress, subname)
#     428         logger.info("loaded %s", fname)
#     429         return obj
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/gensim/utils.py in _load_specials(self, fname, mmap, compress, subname)
#     456             logger.info("loading %s recursively from %s.* with mmap=%s", attrib, cfname, mmap)
#     457             with ignore_deprecation_warning():
# --> 458                 getattr(self, attrib)._load_specials(cfname, mmap, compress, subname)
#     459
#     460         for attrib in getattr(self, '__numpys', []):
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/gensim/utils.py in _load_specials(self, fname, mmap, compress, subname)
#     467                 val = np.load(subname(fname, attrib))['val']
#     468             else:
# --> 469                 val = np.load(subname(fname, attrib), mmap_mode=mmap)
#     470
#     471             with ignore_deprecation_warning():
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     451             else:
#     452                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 453                                          pickle_kwargs=pickle_kwargs)
#     454         else:
#     455             # Try a pickle
#
# ~/jupyter-projects/sentiment-analysis-from-probabilistic-to-deep-learning/venv/lib/python3.6/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     753         if isfileobj(fp):
#     754             # We can use the fast fromfile() function.
# --> 755             array = numpy.fromfile(fp, dtype=dtype, count=count)
#     756         else:
#     757             # This is not a real file. We have to read it the
#
# KeyboardInterrupt:

# %%
# %load_ext autoreload
# %autoreload

from my_word2vec import MyWord2Vec

import pickle

# %%
for nc, c in list(corpus.items())[:1]:
    for d in dims[:1]:
        for w in windows[:1]:
            for ite in iters[:1]:
                name = "{}_{}_{}_{}".format(nc, str(d), str(w), ite)
                print(name)
                my_word2vec = MyWord2Vec(dim=300, window_size=2, epoch=5, batch_size=10, buffer_size=100, ignore=["."])
                vec, int2word = my_word2vec.train(c)
                with open(name + "_my_word2vec.pkl", "wb") as f:
                    pickle.dump((vec, int2word), f)
                break
# Out:
# case_300_5_5
# (24764742, 102832)

# %%
from word_emb import run_logistic_word_emb_exp

# %%
import pickle
import gensim
# %load_ext autoreload
# %autoreload
from word_emb import run_logistic_word_emb_exp

from gensim.models import Word2Vec, KeyedVectors
import spacy
from dataset import download_tfds_imdb_as_text
nlp = spacy.load("en_core_web_sm")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class WV:
    def __init__(self, dic):
        self.dic = dic
        self.vector_size = 300
    def __getitem__(self, key):
        return self.dic[key]
    
    def __contains__(self, key):
        return key in self.dic
    
X_train, X_test, y_train, y_test = download_tfds_imdb_as_text()
# Out:
# number of training samples 25000
# number of testing samples 25000

# %%
word_emb_models = {
#     "word2vec": gensim.models.KeyedVectors.load_word2vec_format('./GoogleNews-vectors-negative300.bin', binary=True),
    "mywv": WV(pickle.load(open("wv_20200531-remove-punct-digit.pkl", "rb")))
}

# %%
run_logistic_word_emb_exp(X_train, X_test, y_train, y_test, word_emb_models)
# Out:
#   word_emb_model  tfidf              tokenizer polling        F1
# 0           mywv  False  spacy_tokenizer_lower     LOG  0.763795
